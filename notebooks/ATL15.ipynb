# %%
import earthaccess

auth = earthaccess.login()

results = earthaccess.search_data(
    short_name = "ATL15",
    cloud_hosted= True,
    temporal=("2021-01","2021-02"),
    count = 1
)
results[0]
# Out:
# EARTHDATA_USERNAME and EARTHDATA_PASSWORD are not set in the current environment, try setting them or use a different strategy (netrc, interactive)
# You're now authenticated with NASA Earthdata Login
# Using token with expiration date: 09/30/2023
# Using .netrc file for EDL
# Granules found: 28
# Collection: {'EntryTitle': 'ATLAS/ICESat-2 L3B Gridded Antarctic and Arctic Land Ice Height Change V002'}
# ...

# %%
files = earthaccess.open(results, "ATL15")
# Out:
#  Opening 1 granules, approx size: 0.01 GB
# QUEUEING TASKS | : 0it [00:00, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import xarray as xr
import h5netcdf

ds = h5netcdf.File(files[0])
ds
# Out:
# <h5netcdf.File 'ATL15_GL_0314_10km_002_01.nc>' (mode r)>
# Dimensions:
# Groups:
#     tile_stats
#     delta_h
#     dhdt_lag1
#     dhdt_lag4
#     dhdt_lag8
#     dhdt_lag12
#     METADATA
#     orbit_info
#     quality_assessment
# Variables:
# Attributes:
#     GDAL_AREA_OR_POINT: 'Area'
#     Conventions: 'CF-1.6'
#     short_name: 'ATL15'
#     level: 'L3B'
#     title: 'SET_BY_META'
#     description: 'This data set (ATL15) contains seasonal, annual, and biennial gridded land ice elevation change.'
# ...

# %%
ds = xr.open_dataset(files[0], group="dhdt_lag1")
ds
# Out:
# <xarray.Dataset>
# Dimensions:              (x: 154, y: 270, time: 14)
# Coordinates:
#   * x                    (x) float64 -6.67e+05 -6.57e+05 ... 8.55e+05 8.65e+05
#   * y                    (y) float64 -3.347e+06 -3.337e+06 ... -6.57e+05
#   * time                 (time) datetime64[ns] 2018-11-16T14:15:00 ... 2022-0...
# Data variables:
#     Polar_Stereographic  int8 ...
#     ice_area             (time, y, x) float32 ...
#     dhdt                 (time, y, x) float32 ...
#     dhdt_sigma           (time, y, x) float32 ...
# Attributes:
#     description:  dhdt_lag1 group includes variables describing height differ...

# %%
import hvplot.xarray

ds.ice_area.hvplot(x="x", y="y", aspect="equal", cmap="ocean", height=400)
# Out:
# WARNING:param.RasterPlot02112: Due to internal constraints, when aspect and width/height is set, the bokeh backend uses those values as frame_width/frame_height instead. This ensures the aspect is respected, but means that the plot might be slightly larger than anticipated. Set the frame_width/frame_height explicitly to suppress this warning.
# :DynamicMap   [time]
#    :Image   [x,y]   (ice_area)
